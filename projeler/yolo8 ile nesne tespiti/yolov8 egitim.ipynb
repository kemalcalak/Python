# %% [markdown]
# **Google Drive Bağlantısı**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# **Dosyaları Zipten Çıkarma**

# %%
# !unzip /content/drive/MyDrive/data_f1.zip
# Out:
# Archive:  /content/drive/MyDrive/data_f1.zip
# replace data_f1/images/train/astonmartin.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %% [markdown]
# **Kurulumlar**

# %%
# !pip install ultralytics
# !git clone https://github.com/ultralytics/ultralytics.git
# %cd /content/ultralytics

# %%
# !yolo mode=checks
from ultralytics import YOLO
from IPython.display import display, Image
# %cd /content/ultralytics

# %% [markdown]
# **Eğitim**

# %%
# !yolo task=detect mode=train model=yolov8x.pt data=custom.yaml epochs=25 imgsz=1280 batch=4 optimizer=SGD lr0=0.01 device=0

# %% [markdown]
# **TensorBoard**

# %%
# %load_ext tensorboard
# %tensorboard --logdir /content/ultralytics/runs/detect/train

# %% [markdown]
# **Test (Eval)**

# %%
# !yolo task=detect mode=val model=/content/ultralytics/runs/detect/train5/weights/best.pt data=custom.yaml

# %%
from IPython.display import display, Image
Image(filename=f'/content/ultralytics/runs/detect/train5/confusion_matrix.png', width=600)

# %% [markdown]
# **Resim Üzerinden Test**

# %%
# !yolo task=detect mode=predict model=/content/ultralytics/runs/detect/train5/weights/best.pt conf=0.60 source=/content/data_f1/images/val/

# %% [markdown]
# **Video Üzerinden Test**

# %%
# !yolo task=detect mode=predict model=/content/ultralytics/runs/detect/train5/weights/best.pt conf=0.50 source=/content/drive/MyDrive/qatarf1.mp4
