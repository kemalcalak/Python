# %% [markdown]
# **Google Drive Bağlantısı**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Dosyaları Zipten Çıkarma**

# %%
# !unzip /content/drive/MyDrive/datalar.zip
# Out:
# Görüntülenen çıkış son 5000 satıra kısaltıldı.
#   inflating: datalar/teknofest hazirlik/VisDrone2019-DET-train/images/9999951_00000_d_0000239.jpg
#   inflating: datalar/teknofest hazirlik/VisDrone2019-DET-train/images/9999951_00000_d_0000240.jpg
#   inflating: datalar/teknofest hazirlik/VisDrone2019-DET-train/images/9999951_00000_d_0000241.jpg
#   inflating: datalar/teknofest hazirlik/VisDrone2019-DET-train/images/9999951_00000_d_0000242.jpg
#   inflating: datalar/teknofest hazirlik/VisDrone2019-DET-train/images/9999951_00000_d_0000243.jpg
#   inflating: datalar/teknofest hazirlik/VisDrone2019-DET-train/images/9999951_00000_d_0000244.jpg
#   inflating: datalar/teknofest hazirlik/VisDrone2019-DET-train/images/9999951_00000_d_0000245.jpg
#   inflating: datalar/teknofest hazirlik/VisDrone2019-DET-train/images/9999951_00000_d_0000246.jpg
#   inflating: datalar/teknofest hazirlik/VisDrone2019-DET-train/images/9999951_00000_d_0000247.jpg
# ...

# %% [markdown]
# **Kurulumlar**

# %%
# !pip install ultralytics
# !git clone https://github.com/ultralytics/ultralytics.git
# %cd /content/ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 616.5/616.5 kB 4.7 MB/s eta 0:00:00
# ...
# Cloning into 'ultralytics'...
# remote: Enumerating objects: 16392, done.
# remote: Counting objects: 100% (107/107), done.
# remote: Compressing objects: 100% (89/89), done.
# remote: Total 16392 (delta 49), reused 47 (delta 18), pack-reused 16285
# Receiving objects: 100% (16392/16392), 8.74 MiB | 12.42 MiB/s, done.
# Resolving deltas: 100% (11359/11359), done.
# /content/ultralytics

# %%
# !yolo mode=checks
from ultralytics import YOLO
from IPython.display import display, Image
# %cd /content/ultralytics
# Out:
# Traceback (most recent call last):
#   File "C:\anaconda\envs\gpu\lib\runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\anaconda\envs\gpu\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\anaconda\envs\gpu\Scripts\yolo.exe\__main__.py", line 7, in <module>
#   File "C:\anaconda\envs\gpu\lib\site-packages\ultralytics\cfg\__init__.py", line 393, in entrypoint
#     raise ValueError(f"Invalid 'mode={mode}'. Valid modes are {MODES}.\n{CLI_HELP_MSG}")
# ValueError: Invalid 'mode=<module 'ultralytics.utils.checks' from 'C:\\anaconda\\envs\\gpu\\lib\\site-packages\\ultralytics\\utils\\checks.py'>'. Valid modes are ('train', 'val', 'predict', 'export', 'track', 'benchmark').
#
#     Arguments received: ['yolo', 'mode=checks']. Ultralytics 'yolo' commands use the following syntax:
#
#         yolo TASK MODE ARGS
#
#         Where   TASK (optional) is one of ('detect', 'segment', 'classify', 'pose')
# ...

# %%
# !unzip /content/Datalar_1/data_f1.zip
# Out:
# Archive:  /content/Datalar_1/data_f1.zip
#    creating: data_f1/
#    creating: data_f1/images/
#    creating: data_f1/images/train/
#   inflating: data_f1/images/train/bahri02341.jpg
#   inflating: data_f1/images/train/bahri02361.jpg
#   inflating: data_f1/images/train/bahri03561.jpg
#   inflating: data_f1/images/train/bahri03801.jpg
#   inflating: data_f1/images/train/bahri03861.jpg
#   inflating: data_f1/images/train/bahri04081.jpg
#   inflating: data_f1/images/train/bahri04101.jpg
#   inflating: data_f1/images/train/bahri06021.jpg
#   inflating: data_f1/images/train/bahri06141.jpg
#   inflating: data_f1/images/train/bahri06201.jpg
#   inflating: data_f1/images/train/bahri06221.jpg
#   inflating: data_f1/images/train/bahri06541.jpg
#   inflating: data_f1/images/train/bahri06961.jpg
#   inflating: data_f1/images/train/bahri07241.jpg
#   inflating: data_f1/images/train/bahri07661.jpg
#   inflating: data_f1/images/train/bahri07721.jpg
# ...

# %% [markdown]
# **Eğitim**

# %%
# !yolo task=detect mode=train model=yolov8x.pt data=custom.yaml epochs=25 imgsz=1280 batch=4 optimizer=SGD lr0=0.01 device=0
# Out:
# ...
# 100% 131M/131M [00:00<00:00, 271MB/s]
# Ultralytics YOLOv8.0.192 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# **TensorBoard**

# %%
# %load_ext tensorboard
# %tensorboard --logdir /content/ultralytics/runs/detect/train

# %% [markdown]
# **Test (Eval)**

# %%
# !yolo task=detect mode=val model=/content/ultralytics/runs/detect/train/weights/best.pt data=custom.yaml
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/yolo/cfg/__init__.py", line 380, in entrypoint
#     model = YOLO(model, task=task)
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/yolo/engine/model.py", line 107, in __init__
#     self._load(model, task)
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/yolo/engine/model.py", line 156, in _load
#     self.model, self.ckpt = attempt_load_one_weight(weights)
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/nn/tasks.py", line 578, in attempt_load_one_weight
#     ckpt, weight = torch_safe_load(weight)  # load ckpt
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/nn/tasks.py", line 518, in torch_safe_load
#     return torch.load(file, map_location='cpu'), file  # load
# ...

# %%
from IPython.display import display, Image
Image(filename=f'/content/ultralytics/runs/detect/train/confusion_matrix.png', width=600)

# %% [markdown]
# **Resim Üzerinden Test**

# %%
# !yolo task=detect mode=predict model=/content/ultralytics/runs/detect/train5/weights/best.pt conf=0.60 source=/content/data_f1/images/val/

# %% [markdown]
# **Video Üzerinden Test**

# %%
# !yolo task=detect mode=predict model=best.pt conf=0.50 source=f1.mp4
# Out:
# ^C
